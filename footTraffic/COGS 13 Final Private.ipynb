# %% [markdown]
# # Characterizing Foot Traffic at UCSD

# %% [markdown]
# ### Stephen Knox, A14005487
# ### David Amante, A13372333

# %% [markdown]
# This Jupyter Notebook is intended for Federico Rossano's Spring 2018 COGS 13 class. This notebook is used primarily for figures and calculations. We intend to use minimal text here to keep the word count purely in the PDF.

# %% [markdown]
# ## Time Contributed

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# df_tC = df_timeContributed
df_tC = pd.read_csv('timeContributed.csv')

# %%
# Example of time contributed dataframe
df_tC
# Out:
#      person   uni_week   month   day_num     day_str              location  \
# 0     David          1   April         5    Thursday         Peterson Hall
# 1     David          1   April         5    Thursday         Price Theater
# 2     David          1   April         5    Thursday        Galbraith Hall
# 3   Stephen          2   April         9      Monday   Warren Lecture Hall
# 4   Stephen          2   April         9      Monday    Pepper Canyon Hall
# 5     David          2   April        10     Tuesday         Peterson Hall
# 6     David          2   April        10     Tuesday         Price Theater
# 7     David          2   April        10     Tuesday        Galbraith Hall
# 8   Stephen          2   April        11   Wednesday   Warren Lecture Hall
# 9   Stephen          2   April        11   Wednesday    Pepper Canyon Hall
# 10    David          2   April        12    Thursday         Peterson Hall
# 11    David          2   April        12    Thursday         Price Theater
# 12    David          2   April        12    Thursday        Galbraith Hall
# 13  Stephen          2   April        13      Friday   Warren Lecture Hall
# 14  Stephen          2   April        13      Friday    Pepper Canyon Hall
# 15  Stephen          3   April        16      Monday   Warren Lecture Hall
# 16  Stephen          3   April        16      Monday    Pepper Canyon Hall
#
#      minutes_worked  lecture_end_time
# 0                17            9:20AM
# 1                19           12:20PM
# 2                16            1:50PM
# 3                19           11:50AM
# 4                22            3:50PM
# 5                21            9:20AM
# 6                18           12:20PM
# 7                17            1:50PM
# 8                18           11:50AM
# 9                20            3:50PM
# 10               18            9:20AM
# 11               19           12:20PM
# 12               15            1:50PM
# 13               16           11:50AM
# 14               18            3:50PM
# 15               17           11:50AM
# 16               19            3:50PM

# %% [markdown]
# We removed the room numbers from each location because we decided it would be too difficult to track each student entering and exiting each specific room. We believe this would not skew the data in any significant manner.

# %% [markdown]
# ## Stephen's Time Contribution

# %%
# create new dataframe organized by all "Stephen" entries
stephen = df_tC['person'] == "Stephen"
df_tC_Stephen = df_tC[stephen]
df_tC_Stephen.head()
# Out:
#      person   uni_week   month   day_num     day_str              location  \
# 3   Stephen          2   April         9      Monday   Warren Lecture Hall
# 4   Stephen          2   April         9      Monday    Pepper Canyon Hall
# 8   Stephen          2   April        11   Wednesday   Warren Lecture Hall
# 9   Stephen          2   April        11   Wednesday    Pepper Canyon Hall
# 13  Stephen          2   April        13      Friday   Warren Lecture Hall
#
#      minutes_worked  lecture_end_time
# 3                19           11:50AM
# 4                22            3:50PM
# 8                18           11:50AM
# 9                20            3:50PM
# 13               16           11:50AM

# %%
# calculate stephen's data collection contribution
# TC = timeContributed
stephenTC = sum(df_tC_Stephen.iloc[:, 6])

# TE = totalEntries
stephenTE = df_tC_Stephen.iloc[:, 0].count()

print("Stephen's Contributions")
print("- {}\tdata entries".format(stephenTE))
print("- {0:.2f}\thours to data collection.".format(stephenTC / 60))
print("- {0:.2f}\tminutes per entry on average".format(stephenTC / stephenTE))
# Out:
# Stephen's Contributions
# - 8	data entries
# - 2.48	hours to data collection.
# - 18.62	minutes per entry on average

# %% [markdown]
# ## David's Time Contribution

# %%
# create new dataframe organized by all "David" entries
david = df_tC['person'] == "David"
df_tC_David = df_tC[david]
df_tC_David.head()
# Out:
#   person   uni_week   month   day_num    day_str         location  \
# 0  David          1   April         5   Thursday    Peterson Hall
# 1  David          1   April         5   Thursday    Price Theater
# 2  David          1   April         5   Thursday   Galbraith Hall
# 5  David          2   April        10    Tuesday    Peterson Hall
# 6  David          2   April        10    Tuesday    Price Theater
#
#     minutes_worked  lecture_end_time
# 0               17            9:20AM
# 1               19           12:20PM
# 2               16            1:50PM
# 5               21            9:20AM
# 6               18           12:20PM

# %%
# calculated david's data collection contribution
# TC = timeContributed
davidTC = sum(df_tC_David.iloc[:,6])

# TE = totalEntries
davidTE = df_tC_David.iloc[:, 0].count()

# STD = standard deviation of return to low
print("David's Contributions")
print("- {}\tdata entries".format(davidTE))
print("- {0:.2f}\thours to data collection.".format(davidTC / 60))
print("- {0:.2f}\tminutes per entry on average".format(davidTC / davidTE))
# Out:
# David's Contributions
# - 9	data entries
# - 2.67	hours to data collection.
# - 17.78	minutes per entry on average

# %%
print("Collective Contributions")
print("- {}\ttotal entries".format(davidTE + stephenTE))
print("- {}\ttotal hours collecting data".format((davidTC + stephenTC)/60))
print("- {0:.2f}\tminutes of the average data entry".format((davidTC + stephenTC) / (davidTE + stephenTE)))
print("- {0:.2f}\tminutes to return to 'low foot traffic' state on average".format(np.mean(df_tC.iloc[:,6])))
# Out:
# Collective Contributions
# - 17	total entries
# - 5.15	total hours collecting data
# - 18.18	minutes of the average data entry
# - 18.18	minutes to return to 'low foot traffic' state on average

# %% [markdown]
# It's important to note that the "return to low foot traffic" figure and "average data entry" figure are the same because one is defined by the other.
#
# If we recorded data until the state of the area returned to 'low foot traffic', and the length of our data entry is defined by that state, then the two numbers should be the same even though they are calculated differently.

# %% [markdown]
# ## Ethogram Example

# %%
# df_ethogramExample
df_eE = pd.read_csv('ethogram.csv')
df_eE.head(2)
# Out:
#    class_length   early_leave   early_arrive   letout_to_low_traffic  \
# 0            80             6             12                      17
# 1            80             7             13                      19
#
#     questions_for_prof   external_event
# 0                    1                0
# 1                    1                1

# %% [markdown]
# ## Master Dataset

# %%
# mdf = master dataframe (concatenate ethogramexample and timeContributed)
# scroll to the right in the columns below
mdf = pd.concat([df_tC, df_eE], axis=1)
mdf.head()
# Out:
#     person   uni_week   month   day_num    day_str              location  \
# 0    David          1   April         5   Thursday         Peterson Hall
# 1    David          1   April         5   Thursday         Price Theater
# 2    David          1   April         5   Thursday        Galbraith Hall
# 3  Stephen          2   April         9     Monday   Warren Lecture Hall
# 4  Stephen          2   April         9     Monday    Pepper Canyon Hall
#
#     minutes_worked  lecture_end_time  class_length   early_leave  \
# 0               17            9:20AM            80             6
# 1               19           12:20PM            80             7
# 2               16            1:50PM            80             3
# 3               19           11:50AM            50             4
# 4               22            3:50PM            50             6
#
#     early_arrive   letout_to_low_traffic   questions_for_prof   external_event
# 0             12                      17                    1                0
# 1             13                      19                    1                1
# 2              8                      16                    1                0
# 3             16                      19                    1                0
# 4             12                      22                    1                0

# %%
scatter_matrix(mdf, alpha=0.5)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2961: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   'left=%s, right=%s') % (left, right))
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3285: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff08cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff3cda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ff77da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20083cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a200c0da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a200c0dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20126d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20161da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2019dcc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a201756a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cd02c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cffc470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a201f6860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a202207f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d151a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2028e160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a202c51d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a203001d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2033a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20361be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a203a70f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a203de630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20417b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20443940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2047c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a204b5940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a204f0940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a204874e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2055c400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a205958d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a205cfe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a205f5c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20634e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20678240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a206b0240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a206ea6a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20715940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2074f8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20789940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a207c48d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20759780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20830400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2086a860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208a3860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a208df780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20906e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20949390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20984390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a209bf320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a209e7e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20a20ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20a5ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20a91e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20a7a470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20b01a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20b3ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20b77a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20babef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20be5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20c1f470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20c57390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20c90390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20bf4160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20cf2b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20d2cbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20d68b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20d9fa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20dd57f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20e107f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20e4c7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20e80c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20ea1630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20ef3080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20f2b0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20f640f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20f94fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20fc4b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21000be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2103cbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21075be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a210aa780>]],
#       dtype=object)

# %%
mdf.plot()
